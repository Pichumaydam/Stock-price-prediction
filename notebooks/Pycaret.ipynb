# %%
pip install pycaret
# Out:
# ...
#   Using cached pycaret-3.0.4-py3-none-any.whl (484 kB)
# ...
#   Using cached plotly_resampler-0.9.1-py3-none-any.whl (73 kB)
# ...
#   Using cached wurlitzer-3.0.3-py3-none-any.whl (7.3 kB)
# ...
#   Using cached xxhash-3.3.0-cp39-cp39-macosx_10_9_x86_64.whl (31 kB)
# ...
#   Using cached schemdraw-0.15-py3-none-any.whl (106 kB)
# ...
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# ...
#   Using cached lightgbm-4.0.0-py3-none-macosx_10_15_x86_64.macosx_11_6_x86_64.macosx_12_5_x86_64.whl (1.7 MB)
# ...
#   Using cached pyod-1.1.0-py3-none-any.whl
# ...
#   Using cached scikit_plot-0.3.7-py3-none-any.whl (33 kB)
# ...
#   Using cached sktime-0.21.0-py3-none-any.whl (17.1 MB)
# ...
#   Using cached category_encoders-2.6.1-py2.py3-none-any.whl (81 kB)
# ...
#   Using cached tbats-1.1.3-py3-none-any.whl (44 kB)
# ...
#   Using cached imbalanced_learn-0.11.0-py3-none-any.whl (235 kB)
# ...
#   Using cached dash-2.11.1-py3-none-any.whl (10.4 MB)
# ...
#   Attempting uninstall: dash
#     Found existing installation: dash 1.19.0
# ...

# %%
import yfinance as yahooFinance

# in order to specify start date and
# end date we need datetime package
import datetime

# startDate , as per our convenience we can modify
startDate = datetime.datetime(2019, 5, 31)

# endDate , as per our convenience we can modify
endDate = datetime.datetime(2021, 1, 30)
meta = yahooFinance.Ticker("META")

# pass the parameters as the taken dates for start and end
df = meta.history(start=startDate, end=endDate)
df['Date'] = df.index

# %%
from pycaret.time_series import TSForecastingExperiment
exp = TSForecastingExperiment()
exp.setup(data=df, fh=12, session_id=42, fig_kwargs = {"template": "simple_white","hoverinfo":"none"})

top4 = exp.compare_models(n_select = 4)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/may/Desktop/Applied/Github/Stock-price-prediction/notebooks/Pycaret.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/may/Desktop/Applied/Github/Stock-price-prediction/notebooks/Pycaret.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> from pycaret.time_series import TSForecastingExperiment
#       <a href='vscode-notebook-cell:/Users/may/Desktop/Applied/Github/Stock-price-prediction/notebooks/Pycaret.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> exp = TSForecastingExperiment()
# ----> <a href='vscode-notebook-cell:/Users/may/Desktop/Applied/Github/Stock-price-prediction/notebooks/Pycaret.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> exp.setup(data=df, fh=12, session_id=42, fig_kwargs = {"template": "simple_white","hoverinfo":"none"})
# ...
